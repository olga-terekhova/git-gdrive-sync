# %% [markdown]
# <a href="https://colab.research.google.com/github/olga-terekhova/git-gdrive-sync/blob/main/notebooks/Test_GitHub.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
7+6
# Out:
# 13
