# %% [markdown]
# testing sub output

# %% [markdown]
# here goes another change that triggers syncing

# %% [markdown]
# And another change again and again

# %%
2 + 2

# %%
3+ 5

# %%
1+1

# %%
3+3

# %%
5+6

# %%
7-1

# %%
7-8
